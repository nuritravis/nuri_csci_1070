# %% [markdown]
# ![branches.png](attachment:324aee05-9386-4bc3-9047-3476b5af53d6.png)

# %%
the first level are the repos
the level below are the individual folders in my repo and the class repo
the level below that is the files in those folders

# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]

for m in months:
    if m != "November":
        print(m)
    elif m == "November":
        print("my birthday")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# my birthday
# December
